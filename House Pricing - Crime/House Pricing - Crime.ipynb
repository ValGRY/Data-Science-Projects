# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\vikag\Desktop\Data-Science-Projects\House Pricing - Crime\Zillow.csv')

# %%
df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 904    394767       929                          Lamesa, TX        Msa
# 905    753874       930                           Craig, CO        Msa
# 906    394968       931                           Pecos, TX        Msa
# 907    395188       932                          Vernon, TX        Msa
# 908    394743       933                       Ketchikan, AK        Msa
#
#     StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# ...

# %%
df1 = pd.read_csv(r'C:\Users\vikag\Desktop\Data-Science-Projects\House Pricing - Crime\estimated_crimes_1979_2020.csv')

# %%
df1.T
# Out:
#                           0       1        2         3        4     \
# year                      1979    1979     1979      1979     1979
# state_abbr                 NaN      AK       AL        AR       AZ
# state_name                 NaN  Alaska  Alabama  Arkansas  Arizona
# population           220099000  406000  3769000   2180000  2450000
# violent_crime          1208030    1994    15578      7984    14528
# homicide                 21460      54      496       198      219
# rape_legacy            76390.0   292.0   1037.0     595.0   1120.0
# rape_revised               NaN     NaN      NaN       NaN      NaN
# robbery                 480700     445     4127      1626     4305
# aggravated_assault      629480    1203     9918      5565     8884
# property_crime        11041500   23193   144372     70949   177977
# burglary               3327700    5616    48517     21457    48916
# larceny                6601000   15076    83791     45267   116976
# ...
